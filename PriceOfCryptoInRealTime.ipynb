# %% [markdown]
# <a href="https://colab.research.google.com/github/PRUBHTEJ/CrytoCurrencyInRealTime/blob/main/PriceOfCryptoInRealTime.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Description: - 
#This Program gets the price of cryptocurrencies in real time...

# %%
#Import the libraries
from bs4 import BeautifulSoup
import requests
import time

# %%
#get the URL that conatians the price of the cryptocurrency for example:
#      https://www.google.com/search/?q=litecoin+price
url = "https://www.google.com/search?q=bitcoin+price&gl=us&hl=en&pws=0&sxsrf=ALeKk00INWNhc6RptBUDINiPZfXrueD8HA%3A1627745814580&ei=Fm4FYdbdIoOe4-EPu8C9iAU&oq=bitcoin+price&gs_lcp=Cgxnd3Mtd2l6LXNlcnAQAzIHCAAQRxCwAzIHCAAQRxCwAzIHCAAQRxCwAzIHCAAQRxCwAzIHCAAQRxCwAzIHCAAQRxCwAzIHCAAQRxCwAzIHCAAQRxCwAzIHCAAQsAMQQ0oECEEYAFAAWABgoelKaAJwAXgBgAHRAYgBjQSSAQUwLjIuMZgBAMgBCcABAQ&sclient=gws-wiz-serp&ved=0ahUKEwjWwL_Y0Y3yAhUDzzgGHTtgD1EQ4dUDCA4&uact=5"

#make a request to the website"
HTML = requests.get(url)

#Parse the HTML
soup = BeautifulSoup(HTML.text, 'html.parser')

#print soup to find where the text is, that contains the price of the cryptocurrency 
print(soup.prettify())
# Out:
# <!DOCTYPE doctype html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"/>
#   <title>
#    bitcoin price - Google Search
#   </title>
#   <script nonce="+EYfOL9BFMylEWCkr0OD6w==">
#    (function(){
# document.documentElement.addEventListener("submit",function(b){var a;if(a=b.target){var c=a.getAttribute("data-submitfalse");a="1"==c||"q"==c&&!a.elements.q.value?!0:!1}else a=!1;a&&(b.preventDefault(),b.stopPropagation())},!0);document.documentElement.addEventListener("click",function(b){var a;a:{for(a=b.target;a&&a!=document.documentElement;a=a.parentElement)if("A"==a.tagName){a="1"==a.getAttribute("data-nohref");break a}a=!1}a&&b.preventDefault()},!0);}).call(this);(function(){
# ...

# %%
#             <div class="BNeawe iBp4i AP7Wnd">

#Create a function to get the price of a cryptocurrency
def get_crypto_price(coin):
  #get the URL that conatians the price of the cryptocurrency for example:
  #https://www.google.com/search/?q=litecoin+price
  url = 'https://www.google.com/search?q=' + coin + '+price&gl=us&hl=en&pws=0&sxsrf=ALeKk03QUaLg2No1Z_Y_K669EY2_5MfmJw%3A1627745811058&source=hp&ei=E24FYYGMAbWW4-EPnLu3qAU&iflsig=AINFCbYAAAAAYQV8I0Dj2I_RzRhSAl5If-z7lifuF_jy&oq=bitcoin+proce&gs_lcp=&sclient=gws-wiz&ved=0ahUKEwjB4ebW0Y3yAhU1yzgGHZzdDVUQ4dUDCAk&uact=5'

  #make a request to the website"
  HTML = requests.get(url)

  #Parse the HTML
  soup = BeautifulSoup(HTML.text, 'html.parser')

  #Find the Current Price
  text = soup.find('div', attrs = {'class' : 'BNeawe iBp4i AP7Wnd'}). find('div', attrs = {'class' : 'BNeawe iBp4i AP7Wnd'}).text

  #Return the text:
  return text

# %%
#Get the price of the coin
price = get_crypto_price('bitcoin')
print(price)
# Out:
# 41,526.00 United States Dollar

# %%
#This Function shows the price of a crypto in real time.
#Create a main function to consistently show the price of the crypto, when it changes
def main():
  last_price = -1
  #Create a loop to continuosly show the price:
  while True:
    #Choose the crypto that I want to choose the price for:
    crypt = input("Enter the crypto, for which you want to know the price")
    #get the price of the crypto:
    price = get_crypto_price(crypt)
    #Check if the price of crypto has changed?
    if price != last_price:
      print(crypt + ' price '+ ':', price)f
      last_price = price
    time.sleep(3)

# %%
#Run/Excecute the main function
main()
